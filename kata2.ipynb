# %% [markdown]
# # Kata 2 realizar un paquete en virtual environment

# %%
from IPython.display import Image
Image(filename="img/minion.jpg", width=200)

# %% [markdown]
# Vamos a mostrar los screenshots del proceso

# %%
# crear un entorno virtual
Image(filename="img/kata2_1.png", width=500)

# %%
# posicionarse en el directorio del entorno virtual / scripts  y ejecutar activate
Image(filename="img/kata2_2.png", width=500)

# %%
# Instalacion de librerías y consulta de que librerías tenemos
Image(filename="img/kata2_3.png", width=600)
