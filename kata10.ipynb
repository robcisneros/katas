# %% [markdown]
# # Kata 2 Handling errors

# %%
from IPython.display import Image

# %% [markdown]
# # Tracebacks

# %%
# Si intentamos en un notebook, abrir un archivo inexistente sucede lo siguiente:
# open("/path/to/mars.jpg")
# Archivo no existente
Image(filename="img/kata10_1.png", width=1000)

# %%
# La salida menciona que el error se inicia en la línea 5, que incluye la llamada a main(). 
# A continuación, la salida sigue el error a la línea 2 en la llamada de función open(). 
# Y, por último, FileNotFoundError notifica de nuevo que el archivo o el directorio no existen.
Image(filename="img/kata10_2.png", width=700)

# %% [markdown]
# # Controlando las excepciones

# %% [markdown]
# Sabemos que, si no existe un archivo o directorio, se genera FileNotFoundError. Si queremos controlar esa excepción, podemos hacerlo con un bloque try y except:

# %%
# Sabemos que, si no existe un archivo o directorio, se genera FileNotFoundError. Si queremos controlar esa excepción, podemos hacerlo con un bloque try y except:
Image(filename="img/kata2_2.png", width=500)

try:
    open('config.txt')
except FileNotFoundError:
    print("Couldn't find the config.txt file!")
# Out:
# Couldn't find the config.txt file!

# %%
def main():
    try:
        configuration = open('configu.txt')
    except FileNotFoundError:
        print("Couldn't find the config.txt file!")
    except IsADirectoryError:
        print("Found config.txt but it is a directory, couldn't read it")
